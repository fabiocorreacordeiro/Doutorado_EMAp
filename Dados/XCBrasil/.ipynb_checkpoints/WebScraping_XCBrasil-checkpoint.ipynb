# %% [markdown]
# Script para buscar resumos das teses e dissertações na BDTD

# %%
import requests
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import json

# %%
# Function to gather flight information from each page and retur a dataframe
def gather_page(takeoff, page):

    #setup url
    url = ('http://www.xcbrasil.com.br/tracks/world/alltimes/takeoff:'+takeoff+'&sortOrder=DATE&page_num='+page)

    # Request webpage and parser html file
    f = requests.get(url).text 
    soup = bs(f, "html.parser")


    #Gathering fligth information from each page

    datas = []

    for row in soup.find_all('tr', {"class": ["l_row1", "l_row2"]}):

        data = []

         # id
        data.append(row['id'])

        # Get all html tags
        col = row.find_all('td')
            
        #date
        try:
            data.append(col[1].text.strip())
        except:
            data.append(None)
            
        #pilot
        try:
            data.append(col[2].text.split('\n')[0].strip())
        except:
            data.append(None)
        
        #local
        try:
            data.append(col[2].text.split('\n')[1].strip())
        except:
            data.append(None)
        
        #country
        try:
            data.append(col[2].find('img')['title'])
        except:
            data.append(None)
            
        #duration
        try:
            data.append(col[3].text)
        except:
            data.append(None)
            
        #straight_line_distance(km)
        try:
            data.append(col[4].text.split('\xa0')[0])
        except:
            data.append(None)
        
        #olc_distance(km)
        try:
            data.append(col[5].text.split('\xa0')[0])
        except:
            data.append(None)
            
        #olc_pontuation
        try:
            data.append(col[6].text.strip())
        except:
            data.append(None)
            
        #track_class
        try:
            data.append(col[6].find('img')['title'].strip())
        except:
            data.append(None)
            
        #equipment
        try:
            data.append(col[7].find('img')['title'].strip(' -'))
        except:
            data.append(None)
            
        #brands
        try:
            data.append(col[8].find('img')['title'].strip())
        except:
            data.append(None)

        #flightLink
        try:
            data.append('http://www.xcbrasil.com.br'+ col[9].find('a', {"class": "flightLink"})['href'])
        except:
            data.append(None)

        datas.append(data)

    datas[0]
    df = pd.DataFrame(data = datas, columns=['id', 'date', 'pilot', 'local', 'country', 'duration', 
                                             'straight_line_distance(km)', 'olc_distance(km)', 'olc_pontuation', 
                                             'track_class', 'equipment', 'brand', 'flightLink'])

    return(df)

# %%
#takeoff id
takeoff = '8834' 
file_name = takeoff + '_Poco_de_Caldas'

#Rage of pages
page_start = 1
page_end = 137

xc_brasil = pd.DataFrame(columns=['id', 'date', 'pilot', 'local', 'country', 'duration', 
                                  'straight_line_distance(km)', 'olc_distance(km)', 'olc_pontuation', 
                                  'track_class', 'equipment', 'brand', 'flightLink'])

for page in range(page_start, page_end+1):
    xc_brasil = xc_brasil.append(gather_page(takeoff, str(page)), ignore_index=True)
    
    #Save file each 10 itereations 
    if page % 10 == 0:
        xc_brasil.to_csv(file_name)
        print (page, ' pages gathered')
    
print (page_end, ' pages gathered')
        
xc_brasil.to_csv(file_name)
# Out:
# 10  pages gathered
# 20  pages gathered
# 30  pages gathered
# 40  pages gathered
# 50  pages gathered
# 60  pages gathered
# 70  pages gathered
# 80  pages gathered
# 90  pages gathered
# 100  pages gathered
# 110  pages gathered
# 120  pages gathered
# 130  pages gathered
# 137  pages gathered
