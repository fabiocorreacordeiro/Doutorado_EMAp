# %%
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# # Data from Meteorological Station

# %% [markdown]
# Reanding files

# %%
# Creating an empty datafram
station_data = pd.DataFrame()
# Iterate through files of the directory
for file_name in  glob.glob('..\Estacoes_Meteorologicas\Governador Valadares' +'\*.CSV'):
    x = pd.read_csv(file_name, sep=";", skiprows=9, header=None, low_memory=False)
    #Concatenate dataframe
    station_data = pd.concat([station_data,x],axis=0)
    
# Define columns name 
station_data.columns =['Data','Hora UTC','PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
                     'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
                     'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
                     'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
                     'RADIACAO GLOBAL (Kj/m²)','TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
                     'TEMPERATURA DO PONTO DE ORVALHO (°C)','TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
                     'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
                     'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)','UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
                     'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)','UMIDADE RELATIVA DO AR, HORARIA (%)',
                     'VENTO, DIREÇÃO HORARIA (gr) (° (gr))','VENTO, RAJADA MAXIMA (m/s)','VENTO, VELOCIDADE HORARIA (m/s)',
                     'none']

# Sort data by Date and Hour
station_data = station_data.sort_values(['Data','Hora UTC'])

# %%
station_data
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2007-05-27     00:00                            -9999
# 1     2007-05-27     01:00                            -9999
# 2     2007-05-27     02:00                            -9999
# 3     2007-05-27     03:00                            -9999
# 4     2007-05-27     04:00                            -9999
# ...          ...       ...                              ...
# 8779  2020/12/31  1900 UTC                                0
# 8780  2020/12/31  2000 UTC                                0
# 8781  2020/12/31  2100 UTC                                0
# 8782  2020/12/31  2200 UTC                                0
# 8783  2020/12/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 -9999
# 1                                                 -9999
# 2                                                 -9999
# ...

# %% [markdown]
# # Data from XC Brasil

# %%
file_name = '..\XCBrasil\8833_Pico_do_Ibituruna'
flight = pd.read_csv(file_name, sep=",", index_col=0)
flight
# Out:
#                id        date                 pilot                   local  \
# 0      row_492602  24/02/2021   Jean Pierre Acabado  Pico do Ibituruna - BR
# 1      row_492445  23/02/2021   Jean Pierre Acabado  Pico do Ibituruna - BR
# 2      row_492394  23/02/2021   Jean Pierre Acabado  Pico do Ibituruna - BR
# 3      row_492186  22/02/2021   Jean Pierre Acabado  Pico do Ibituruna - BR
# 4      row_492287  22/02/2021         REMULT XAVIER  Pico do Ibituruna - BR
# ...           ...         ...                   ...                     ...
# 14100   row_23416  16/02/2000        Leonardo Lessa  Pico do Ibituruna - BR
# 14101   row_23412  15/02/2000        Leonardo Lessa  Pico do Ibituruna - BR
# 14102   row_23411  14/02/2000        Leonardo Lessa  Pico do Ibituruna - BR
# 14103  row_270684  00/00/2000             CAIO KRIS  Pico do Ibituruna - BR
# 14104  row_387454  27/08/1999  Renato Maia  e Silva  Pico do Ibituruna - BR
#
# ...

# %% [markdown]
# # Technical Bulletin

# %%
pd.read_json('..\Boletins_Tecnicos\Boletins_tecnicos_2008.json', orient= 'index')

# Creating an empty datafram
bulletin_data = pd.DataFrame()
# Iterate through files of the directory
for file_name in  glob.glob('..\Boletins_Tecnicos' +'\*.json'):
    x = pd.read_json(file_name, orient= 'index')
    #Concatenate dataframe
    bulletin_data = pd.concat([bulletin_data,x],axis=0)
    
bulletin_data
# Out:
#                                                                Nível 250 hPA  \
# 2008-01-09 00:00:00+00:00  Na carta de altitude das 00z do dia 01/09, obs...
# 2008-02-09 00:00:00+00:00  Na carta de altitude das 00z do dia 02/09, obs...
# 2008-03-09 00:00:00+00:00  Na carta de altitude da 00z do dia 03/09, obse...
# 2008-04-09 00:00:00+00:00  Na carta de altitude das 00z do dia 04/09, obs...
# 2008-05-09 00:00:00+00:00  Na carta de altitude das 00z do dia 05/09, obs...
# ...                                                                      ...
# 2020-12-27 00:00:00+00:00  Na análise da carta sinótica de 250 hPa da 00 ...
# 2020-12-28 00:00:00+00:00  Na análise da carta sinótica de 250 hPa da 00 ...
# 2020-12-29 00:00:00+00:00  Na análise da carta sinótica de 250 hPa da 00 ...
# 2020-12-30 00:00:00+00:00  Na análise da carta sinótica de 250 hPa da 00 ...
# 2020-12-31 00:00:00+00:00  Na análise da carta sinótica de 250 hPa da 00 ...
#
# ...
